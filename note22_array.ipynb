# %% [markdown]
# for else  loop:
#
# -- The for-else loop in Python is a control flow structure that combines the for loop and else
# statement. The for loop iterates over a sequence of items, and the else statement is executed
# after the loop is completed, provided that the loop was not terminated prematurely by a break statement.
# Here's the basic syntax:
#
# for item in sequence:
#     loop body
# else:
#     else block
#
# -- The sequence can be any iterable object, such as a list, tuple, or string. The loop body is executed
# once for each item in the sequence, and the item variable takes on the value of each item in turn.
#
# -- If the loop completes normally, without encountering a break statement, then the else block is executed.
# This can be useful for executing cleanup code or performing some final action after the loop is finished.
#
# nums=[12,15,18,21,26]
# #get first number divisble by 5 print from list and we want if number is not divisible by 5 then print not found every time
# for num in nums:
#     if num% 5==0:
#         print(num)
#         break
#     else:
#         print("not found")
#
# #get first number divisble by 5 print from list and we want if number is not divisible by 5 then print not found once
#
# nums=[23,24,27,38,29]
# for num in nums:
#     if num% 5==0:
#         print(num)
#         break
# else:
#     print("not found")

# %% [markdown]
# ![image.png](attachment:044646a6-4a5a-4c76-9707-4e13894f2f99.png)

# %% [markdown]
# signed - from negative to positive
# unsigned- only positive from 0

# %%
from array import *
vals= array('i',[1,3,45,7,-3])
print(vals)
# Out:
# array('i', [1, 3, 45, 7, -3])

# %%
from array import *
vals= array('I',[1,3,45,7,8])
print(vals)
# Out:
# array('I', [1, 3, 45, 7, 8])

# %%
from array import *
vals= array('f',[1,3,45,7,3.5])
print(vals)
# Out:
# array('f', [1.0, 3.0, 45.0, 7.0, 3.5])

# %%
from array import *
vals= array('b',[1,3,45,7,-3])
print(vals)
# Out:
# array('b', [1, 3, 45, 7, -3])

# %%
from array import *
vals= array('B',[1,3,45,7,3])
print(vals)
# Out:
# array('B', [1, 3, 45, 7, 3])

# %%
#buffer_info() - address, how many values
from array import *
vals= array('i',[1,3,45,7,-3])
print(vals.buffer_info())
# Out:
# (4401746960, 5)

# %%
#buffer_info() - address, how many values
from array import *
vals= array('i',[1,3,45])
print(vals.buffer_info())
# Out:
# (4400390112, 3)

# %%
#type of the code
from array import *
vals= array('i',[1,3,45])
print(vals.typecode)
# Out:
# i

# %%
#reversing the array
from array import *
vals= array('i',[1,3,45,9])
vals.reverse()
print(vals)
# Out:
# array('i', [9, 45, 3, 1])

# %%
#to print the exact value
from array import *
vals= array('i',[1,3,45])
print(vals[0])
# Out:
# 1

# %%
#to print all the values
from array import *
vals= array('i',[1,3,45])
for i in range(3):
   print(vals[i])
# Out:
# 1
# 3
# 45

# %%
#to print all the characters
from array import *
vals= array('u',['h','i'])
for i in range(2):
   print(vals[i])
# Out:
# h
# i

# %%
#to print all the characters by using different code
from array import *
vals= array('u',['h','i'])
arr=array(vals.typecode, (a for a in vals))
for i in arr:
   print(i)
# Out:
# h
# i

# %%
#to print all the integers in while loop
from array import *
vals= array('i',[2,5,7,9])
arr=array(vals.typecode, (a*a for a in vals))
i=0
while i<len(arr):
    print(arr[i])
    i=i+1
# Out:
# 4
# 25
# 49
# 81

# %%
#to print all the integers using for loop
from array import *
vals= array('i',[2,5,7,9])
arr=array(vals.typecode, (a*a for a in vals))
for i in arr:
    print(i)
# Out:
# 4
# 25
# 49
# 81

# %%
#to print all the integers using for loop
from array import *
vals= array('i',[2,5,7,9])
arr=array(vals.typecode, (a*a for a in vals))
for i in range(4):
    print(arr[i])
# Out:
# 4
# 25
# 49
# 81
